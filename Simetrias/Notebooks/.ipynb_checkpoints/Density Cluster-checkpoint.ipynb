# %%
import sys
import getopt
sys.path.append("D:\\Documentos\\INNOVATE\\GH\\proyectox\\Simetrias\\Utils")
from Visualization_utilities import *
from Utilities import *
from MF import *
from transformation import Transformation
from Signatures import Signature
# Out:
# C:\Users\grmc1\Anaconda3\envs\INNOVATE\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\grmc1\Anaconda3\envs\INNOVATE\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
# C:\Users\grmc1\Anaconda3\envs\INNOVATE\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
dp=Geometry_load(path="D:\\Documentos\\INNOVATE\\lib\\symmetry-detection-reflection\\mesh\\Wine_Bottle.obj",
                    visualization=True,
                    voxel_down_sample=0.02,
                    geometry_type="3DObject")

# %%
indexes=np.arange(np.asarray(dp.points).shape[0])
pt = o3d.geometry.KDTreeFlann(dp)
signatures=Signature(dp,pt,indexes)
Signature().v_build(signatures,NN_Criteria="KNN",
                    rad=np.std(np.asarray(dp.points)-np.mean(np.asarray(dp.points),axis=0))/4,
                    NN=30)
# Out:
# array([None, None, None, ..., None, None, None], dtype=object)

# %%
signaturesp=remove_discontinuities_by_curvature(dp,signatures,pt,curvature=0.4,radius=0.02)
print(len(signaturesp))
# Out:
# 19354

# %%
pp=prune_points(signaturesp,"sphericity",0.0001)
print("numero de puntos umbilicales")
print(len(pp))
# Out:
# numero de puntos umbilicales
# 19030

# %%
rat=0.1/16
ppp=random_sample(pp,rat)
print("numero de puntos aleatorios")
print(len(ppp))
np.asarray(dp.points).shape
# Out:
# numero de puntos aleatorios
# 118
# (19354, 3)

# %%
[trans_s,rs,KDT,query]=build_pairing_kd_tree(dp,pp,rad=10000.6,rand_samp_percentage=rat,
                                             rigid=True,only_reflections=True,NN=50)
print("numero de puntos en el espacio de transformadas")
print(len(trans_s))
z=0
points=Transformation().v_toPoint(trans_s[:,z])
print("z=0")
print(points)
# Out:
# numero de puntos en el espacio de transformadas
# 5782
# z=0
# [[ 1.00000000e-02 -2.30346152e-02  2.64851334e-04 ...  4.03981006e-03
#   -4.96909510e-03  4.15502569e-02]
#  [ 1.00000000e-02 -1.47972281e-02  7.98658056e-03 ... -1.35761564e-02
#   -1.31049529e-03  1.12176266e-01]
#  [ 1.00000000e-02  2.34165793e-02 -3.09578098e-01 ...  4.92427197e-02
#    9.81345107e-03  7.87118018e-02]
#  ...
#  [ 1.00000000e-02 -9.02862836e-03  1.97749950e-02 ...  6.39220281e-02
#    3.57414919e-02  4.65814777e-02]
#  [ 1.00000000e-02 -4.02449634e-02  5.76164125e-02 ...  5.50835157e-02
#    6.51803180e-02  3.34533878e-02]
#  [ 1.00000000e-02  6.44689828e-03  2.09246466e-03 ... -3.64945541e-02
#   -5.23569479e-02 -2.73624029e-02]]

# %%
embedding= MDS(n_components=2,n_jobs=4)
points2d = embedding.fit_transform(points)
print("z=0")
print(points2d)

bd=4.5*(((np.max(points2d[:,0])*1.2-np.min(points2d[:,0])*1.8)/200+(np.max(points2d[:,0])*1.2-np.min(points2d[:,0])*1.8)/200)/2)
print(bd)

modelo_kde=KernelDensity(kernel='epanechnikov',bandwidth=bd).fit(points2d)
densityPlot(modelo_kde,points2d)
# Out:
# z=0
# [[ 0.0857126   0.10751468]
#  [ 0.0313812   0.03180525]
#  [ 0.28478678  0.00184684]
#  ...
#  [-0.20182197 -0.26266609]
#  [-0.15019685 -0.24069075]
#  [ 0.0106848  -0.01408475]]
# 0.027455246705403537

# %%
points7d=Transformation().v_toPoint(trans_s[:,z])
modelo_kde=KernelDensity(kernel='epanechnikov',bandwidth=bd).fit(points2d)

# %%
x=np.linspace(np.min(points[:,0])*1.8,np.max(points[:,0])*1.2,200)
y=np.linspace(np.min(points[:,1])*1.8,np.max(points[:,1])*1.2,200)
# Out:
# {'algorithm': 'auto',
#  'atol': 0,
#  'bandwidth': 0.027455246705403537,
#  'breadth_first': True,
#  'kernel': 'epanechnikov',
#  'leaf_size': 40,
#  'metric': 'euclidean',
#  'metric_params': None,
#  'rtol': 0}
